# %% [markdown]
# # Data Exploration and Cleaning
# ## 01. Import Data
# ## 02. Data Profiling
# ## 03. Data Wrangling
# ## 04. Cleaning
# ### A. Rename and remove columns
# ### B. Check data types, value formatting, and make corrections
# ## 05. Exploratory Analyses
# ### A. Initial descriptive statistics
# ### B. Explore state level aggregation
# ### C. Explore County Level Aggregation
# ### D. Check stats after separation of county and state aggregation

# %% [markdown]
# # 01. Import Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# create path shortcut
path = r'/Users/mindydong/Documents/Data Analyst/Achievement 6 /Medicare QPP/'

# %%
# import data 
df_qpp = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'market_saturation.csv'), index_col = False, low_memory= False)

# %% [markdown]
# # 02. Data Profiling

# %%
df_qpp.shape
# Out:
# (990509, 48)

# %%
df_qpp.head()
# Out:
#            reference_period                        type_of_service  \
# 0  2018-01-01 to 2018-12-31  Ambulance (Emergency & Non-Emergency)
# 1  2018-01-01 to 2018-12-31  Ambulance (Emergency & Non-Emergency)
# 2  2018-01-01 to 2018-12-31  Ambulance (Emergency & Non-Emergency)
# 3  2018-01-01 to 2018-12-31  Ambulance (Emergency & Non-Emergency)
# 4  2018-01-01 to 2018-12-31  Ambulance (Emergency & Non-Emergency)
#
#       aggregation_level    state   county state_fips county_fips  \
# 0  NATION + TERRITORIES  --ALL--  --ALL--
# 1                 STATE       AL  --ALL--         01
# 2                 STATE       AK  --ALL--         02
# 3                 STATE       AZ  --ALL--         04
# 4                 STATE       AR  --ALL--         05
#
#   number_of_fee_for_service_beneficiaries number_of_providers  \
# 0                              34,139,906               8,784
# 1                                 528,819                 149
# 2                                  65,846                  32
# 3                                 679,296                 176
# 4                                 421,631                  89
#
#   average_number_of_users_per_provider  ...  \
# 0                               489.44  ...
# 1                               497.20  ...
# 2                               212.88  ...
# 3                               376.38  ...
# 4                               597.22  ...
#
#   number_of_fee_for_service_beneficiaries_change number_of_providers_change  \
# 0                                       (18.48%)                   ( 2.57%)
# 1                                       (24.34%)                   ( 2.61%)
# 2                                       (32.59%)                   ( 3.03%)
# 3                                       (17.75%)                   ( 2.76%)
# 4                                       (19.68%)                   (10.10%)
#
#   average_number_of_users_per_provider_change  \
# 0                                    (12.69%)
# 1                                    (19.34%)
# 2                                    (18.09%)
# 3                                    (15.98%)
# 4                                    ( 7.62%)
#
#   percentage_of_users_out_of_ffs_beneficiaries_change number_of_users_change  \
# 0                                              4.31%                (14.94%)
# 1                                              3.85%                (21.45%)
# 2                                             17.88%                (20.58%)
# 3                                           ( 0.71%)                (18.30%)
# 4                                              3.45%                (16.95%)
#
#   average_number_of_providers_per_county_change  \
# 0                                      ( 6.44%)
# 1                                      (12.34%)
# 2                                      ( 2.22%)
# 3                                      ( 1.37%)
# 4                                      ( 4.11%)
#
#   number_of_dual_eligible_users_change  \
# 0                             ( 2.84%)
# 1                             ( 9.28%)
# 2                                3.71%
# 3                             ( 0.59%)
# 4
#
#   percentage_of_dual_eligible_users_out_of_total_users_change  \
# 0                                             14.24%
# 1                                             15.48%
# 2                                             30.58%
# 3                                             21.65%
# 4
#
#   percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change  \
# 0                                           ( 0.86%)
# 1                                           ( 4.07%)
# 2                                           ( 1.08%)
# 3                                           ( 2.36%)
# 4
#
#   total_payment_change
# 0             (12.36%)
# 1             (18.24%)
# 2             (15.54%)
# 3             (17.17%)
# 4             (14.32%)
#
# [5 rows x 48 columns]

# %%
df_qpp.tail()
# Out:
#                 reference_period type_of_service aggregation_level state  \
# 990504  2022-01-01 to 2022-12-31    Telemedicine            COUNTY    WY
# 990505  2022-01-01 to 2022-12-31    Telemedicine            COUNTY    WY
# 990506  2022-01-01 to 2022-12-31    Telemedicine            COUNTY    WY
# 990507  2022-01-01 to 2022-12-31    Telemedicine            COUNTY    WY
# 990508  2022-01-01 to 2022-12-31    Telemedicine            COUNTY    WY
#
#             county state_fips county_fips  \
# 990504  Sweetwater         56         037
# 990505       Teton         56         039
# 990506       Uinta         56         041
# 990507    Washakie         56         043
# 990508      Weston         56         045
#
#        number_of_fee_for_service_beneficiaries number_of_providers  \
# 990504                                   7,340                   3
# 990505                                   4,028                   0
# 990506                                   3,542                   0
# 990507                                   2,022                   1
# 990508                                   1,741                   1
#
#        average_number_of_users_per_provider  ...  \
# 990504                               144.00  ...
# 990505                                       ...
# 990506                                       ...
# 990507                                58.00  ...
# 990508                                41.00  ...
#
#        number_of_fee_for_service_beneficiaries_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        number_of_providers_change average_number_of_users_per_provider_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        percentage_of_users_out_of_ffs_beneficiaries_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        number_of_users_change average_number_of_providers_per_county_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        number_of_dual_eligible_users_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        percentage_of_dual_eligible_users_out_of_total_users_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change  \
# 990504
# 990505
# 990506
# 990507
# 990508
#
#        total_payment_change
# 990504
# 990505
# 990506
# 990507
# 990508
#
# [5 rows x 48 columns]

# %% [markdown]
# # 03. Data Wrangling

# %%
#check for missing values
df_qpp.isnull().sum()
# Out:
# reference_period                                                                            0
# type_of_service                                                                             0
# aggregation_level                                                                           0
# state                                                                                       0
# county                                                                                      0
# state_fips                                                                                  0
# county_fips                                                                                 0
# number_of_fee_for_service_beneficiaries                                                     0
# number_of_providers                                                                         0
# average_number_of_users_per_provider                                                        0
# percentage_of_users_out_of_ffs_beneficiaries                                                0
# number_of_users                                                                             0
# average_number_of_providers_per_county                                                      0
# number_of_dual_eligible_users                                                               0
# percentage_of_dual_eligible_users_out_of_total_users                                        0
# percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries                    0
# total_payment                                                                               0
# moratorium                                                                                  0
# number_of_fee_for_service_beneficiaries_dual_color                                          0
# number_of_fee_for_service_beneficiaries_description                                         0
# number_of_providers_dual_color                                                              0
# number_of_providers_description                                                             0
# average_number_of_users_per_provider_dual_color                                             0
# average_number_of_users_per_provider_description                                            0
# percentage_of_users_out_of_ffs_beneficiaries_dual_color                                     0
# percentage_of_users_out_of_ffs_beneficiaries_description                                    0
# number_of_users_dual_color                                                                  0
# \tnumber_of_users_description                                                               0
# average_number_of_providers_per_county_dual_color                                           0
# average_number_of_providers_per_county_description                                          0
# number_of_dual_eligible_users_dual_color                                                24220
# number_of_dual_eligible_users_description                                               24220
# percentage_of_dual_eligible_users_out_of_total_users_dual_color                         24220
# percentage_of_dual_eligible_users_out_of_total_users_description                        24220
# percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color     24220
# percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description    24220
# total_payment_dual_color                                                                    0
# total_payment_description                                                                   0
# number_of_fee_for_service_beneficiaries_change                                              0
# number_of_providers_change                                                                  0
# average_number_of_users_per_provider_change                                                 0
# percentage_of_users_out_of_ffs_beneficiaries_change                                         0
# number_of_users_change                                                                      0
# average_number_of_providers_per_county_change                                               0
# number_of_dual_eligible_users_change                                                        0
# percentage_of_dual_eligible_users_out_of_total_users_change                                 0
# percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change             0
# total_payment_change                                                                        0
# dtype: int64

# %%
#check for duplicates
df_dups = df_qpp [df_qpp.duplicated()]
df_dups
#no dupliates
# Out:
# Empty DataFrame
# Columns: [reference_period, type_of_service, aggregation_level, state, county, state_fips, county_fips, number_of_fee_for_service_beneficiaries, number_of_providers, average_number_of_users_per_provider, percentage_of_users_out_of_ffs_beneficiaries, number_of_users, average_number_of_providers_per_county, number_of_dual_eligible_users, percentage_of_dual_eligible_users_out_of_total_users, percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries, total_payment, moratorium, number_of_fee_for_service_beneficiaries_dual_color, number_of_fee_for_service_beneficiaries_description, number_of_providers_dual_color, number_of_providers_description, average_number_of_users_per_provider_dual_color, average_number_of_users_per_provider_description, percentage_of_users_out_of_ffs_beneficiaries_dual_color, percentage_of_users_out_of_ffs_beneficiaries_description, number_of_users_dual_color, 	number_of_users_description, average_number_of_providers_per_county_dual_color, average_number_of_providers_per_county_description, number_of_dual_eligible_users_dual_color, number_of_dual_eligible_users_description, percentage_of_dual_eligible_users_out_of_total_users_dual_color, percentage_of_dual_eligible_users_out_of_total_users_description, percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color, percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description, total_payment_dual_color, total_payment_description, number_of_fee_for_service_beneficiaries_change, number_of_providers_change, average_number_of_users_per_provider_change, percentage_of_users_out_of_ffs_beneficiaries_change, number_of_users_change, average_number_of_providers_per_county_change, number_of_dual_eligible_users_change, percentage_of_dual_eligible_users_out_of_total_users_change, percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change, total_payment_change]
# Index: []
#
# [0 rows x 48 columns]

# %% [markdown]
# No duplicates found

# %%
#check for mixed-type data
for col in df_qpp.columns.tolist():
  weird = (df_qpp[[col]].applymap(type) != df_qpp[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_qpp[weird]) > 0:
    print (col)
# Out:
# number_of_dual_eligible_users_dual_color
# number_of_dual_eligible_users_description
# percentage_of_dual_eligible_users_out_of_total_users_dual_color
# percentage_of_dual_eligible_users_out_of_total_users_description
# percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color
# percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description

# %% [markdown]
# # 04. Cleaning

# %% [markdown]
# ## A. Rename and remove columns

# %%
#check column names
df_qpp.columns
# Out:
# Index(['reference_period', 'type_of_service', 'aggregation_level', 'state',
#        'county', 'state_fips', 'county_fips',
#        'number_of_fee_for_service_beneficiaries', 'number_of_providers',
#        'average_number_of_users_per_provider',
#        'percentage_of_users_out_of_ffs_beneficiaries', 'number_of_users',
#        'average_number_of_providers_per_county',
#        'number_of_dual_eligible_users',
#        'percentage_of_dual_eligible_users_out_of_total_users',
#        'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries',
#        'total_payment', 'moratorium',
#        'number_of_fee_for_service_beneficiaries_dual_color',
#        'number_of_fee_for_service_beneficiaries_description',
#        'number_of_providers_dual_color', 'number_of_providers_description',
#        'average_number_of_users_per_provider_dual_color',
#        'average_number_of_users_per_provider_description',
#        'percentage_of_users_out_of_ffs_beneficiaries_dual_color',
#        'percentage_of_users_out_of_ffs_beneficiaries_description',
#        'number_of_users_dual_color', '\tnumber_of_users_description',
#        'average_number_of_providers_per_county_dual_color',
#        'average_number_of_providers_per_county_description',
#        'number_of_dual_eligible_users_dual_color',
#        'number_of_dual_eligible_users_description',
#        'percentage_of_dual_eligible_users_out_of_total_users_dual_color',
#        'percentage_of_dual_eligible_users_out_of_total_users_description',
#        'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color',
#        'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description',
#        'total_payment_dual_color', 'total_payment_description',
#        'number_of_fee_for_service_beneficiaries_change',
#        'number_of_providers_change',
#        'average_number_of_users_per_provider_change',
#        'percentage_of_users_out_of_ffs_beneficiaries_change',
#        'number_of_users_change',
#        'average_number_of_providers_per_county_change',
#        'number_of_dual_eligible_users_change',
#        'percentage_of_dual_eligible_users_out_of_total_users_change',
#        'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change',
#        'total_payment_change'],
#       dtype='object')

# %%
#drop unncessary columns
df_qpp.drop(df_qpp.loc[:,'number_of_fee_for_service_beneficiaries_dual_color':'total_payment_change'], axis = 1, inplace = True)

# %%
# dropping additional columns
df_qpp.drop (['state_fips', 'county_fips','percentage_of_users_out_of_ffs_beneficiaries',
'percentage_of_dual_eligible_users_out_of_total_users','percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries'], axis = 1, inplace = True)

# %%
#rename type of service to service_type
df_qpp.rename(columns = {'type_of_service' : 'service_type'}, inplace = True)

# %%
#rename reference_period to year
df_qpp.rename(columns = {'reference_period' : 'year'}, inplace = True)

# %%
#rename number_of_fee_for_service_beneficiaries to number_ffs_members
df_qpp.rename(columns = {'number_of_fee_for_service_beneficiaries' : 'number_ffs_members'}, inplace = True)

# %%
#rename other columns with long names
df_qpp.rename(columns = {'average_number_of_users_per_provider' : 'avg_user_per_provider','average_number_of_providers_per_county': 'avg_provider_per_county' }, inplace = True)

# %%
#check output
df_qpp.columns
# Out:
# Index(['year', 'service_type', 'aggregation_level', 'state', 'county',
#        'number_ffs_members', 'number_of_providers', 'avg_user_per_provider',
#        'number_of_users', 'avg_provider_per_county',
#        'number_of_dual_eligible_users', 'total_payment', 'moratorium'],
#       dtype='object')

# %% [markdown]
# ## B. Check data types, value formatting, and make corrections

# %%
# check data types
df_qpp.dtypes
# Out:
# year                             object
# service_type                     object
# aggregation_level                object
# state                            object
# county                           object
# number_ffs_members               object
# number_of_providers              object
# avg_user_per_provider            object
# number_of_users                  object
# avg_provider_per_county          object
# number_of_dual_eligible_users    object
# total_payment                    object
# moratorium                       object
# dtype: object

# %%
# list of columns to remove commas
columns_to_clean = ['number_ffs_members', 'number_of_providers', 'number_of_users']

# remove commas from the selected columns
df_qpp[columns_to_clean] = df_qpp[columns_to_clean].applymap(lambda x: int(x.replace(',', '')))

# confirm the updated data types
df_qpp.dtypes
# Out:
# year                             object
# service_type                     object
# aggregation_level                object
# state                            object
# county                           object
# number_ffs_members                int64
# number_of_providers               int64
# avg_user_per_provider            object
# number_of_users                   int64
# avg_provider_per_county          object
# number_of_dual_eligible_users    object
# total_payment                    object
# moratorium                       object
# dtype: object

# %%
# list of columns to remove commas to convert to float
columns_convert = ['avg_user_per_provider', 'avg_provider_per_county']

# remove commas and convert to float for the selected columns
df_qpp[columns_convert] = df_qpp[columns_convert].applymap(lambda x: float(x.replace(',', '')) if x.strip() != '' else 'NaN')

# confirm the updated data types
df_qpp.dtypes
# Out:
# year                              object
# service_type                      object
# aggregation_level                 object
# state                             object
# county                            object
# number_ffs_members                 int64
# number_of_providers                int64
# avg_user_per_provider             object
# number_of_users                    int64
# avg_provider_per_county          float64
# number_of_dual_eligible_users     object
# total_payment                     object
# moratorium                        object
# dtype: object

# %%
#change reference_period values to display only years
df_qpp['year'] = df_qpp['year'].str.split(' to ')

start_dates = pd.to_datetime(df_qpp['year'].str[0])
end_dates = pd.to_datetime(df_qpp['year'].str[1])

df_qpp['year'] = start_dates.dt.strftime('%Y')

# %%
#confirm range was removed and only year remains
df_qpp['year'].head()
# Out:
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# Name: year, dtype: object

# %%
# remove dollar sign and commas from total payment and change dtype to float
df_qpp['total_payment'] = df_qpp['total_payment'].str.replace(',', '').str.replace('$', '').astype(float)
# Out:
# /var/folders/2d/wsjd0mc13vl4q6p45np_hyx00000gn/T/ipykernel_2109/4151815809.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_qpp['total_payment'] = df_qpp['total_payment'].str.replace(',', '').str.replace('$', '').astype(float)

# %%
#confirm removal of dollar sign and commas
df_qpp['total_payment'].head(15)
# Out:
# 0     3.966064e+09
# 1     7.676008e+07
# 2     5.690912e+06
# 3     4.592878e+07
# 4     4.777772e+07
# 5     3.354311e+08
# 6     3.312693e+07
# 7     6.666871e+07
# 8     1.615931e+07
# 9     7.328845e+06
# 10    2.254507e+08
# 11    1.943569e+08
# 12    6.333642e+06
# 13    1.098577e+07
# 14    1.801606e+08
# Name: total_payment, dtype: float64

# %%
df_qpp.head()
# Out:
#    year                           service_type     aggregation_level    state  \
# 0  2018  Ambulance (Emergency & Non-Emergency)  NATION + TERRITORIES  --ALL--
# 1  2018  Ambulance (Emergency & Non-Emergency)                 STATE       AL
# 2  2018  Ambulance (Emergency & Non-Emergency)                 STATE       AK
# 3  2018  Ambulance (Emergency & Non-Emergency)                 STATE       AZ
# 4  2018  Ambulance (Emergency & Non-Emergency)                 STATE       AR
#
#     county  number_ffs_members  number_of_providers avg_user_per_provider  \
# 0  --ALL--            34139906                 8784                489.44
# 1  --ALL--              528819                  149                 497.2
# 2  --ALL--               65846                   32                212.88
# 3  --ALL--              679296                  176                376.38
# 4  --ALL--              421631                   89                597.22
#
#    number_of_users  avg_provider_per_county number_of_dual_eligible_users  \
# 0          4299207                    39.38                     1,417,851
# 1            74083                    12.08                        27,907
# 2             6812                     6.60                         2,824
# 3            66243                    69.63                        13,476
# 4            53153                     8.16
#
#    total_payment moratorium
# 0   3.966064e+09
# 1   7.676008e+07         No
# 2   5.690912e+06         No
# 3   4.592878e+07         No
# 4   4.777772e+07         No

# %%
#export to pickle
df_qpp.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'msu_clean.pkl'))

# %%
df_qpp.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'msu_clean.csv'))

# %% [markdown]
# # 05. Exploratory analyses

# %% [markdown]
# ## A. Initial descriptive statistics

# %%
#check statistics
df_qpp.describe()
# Out:
#        number_ffs_members  number_of_providers  number_of_users  \
# count        9.905090e+05        990509.000000     9.905090e+05
# mean         3.810795e+04            46.382853     5.422744e+03
# std          7.018313e+05          1250.799749     1.578245e+05
# min          1.900000e+01             0.000000     1.100000e+01
# 25%          2.203000e+03             2.000000     8.800000e+01
# 50%          4.539000e+03             5.000000     3.100000e+02
# 75%          1.177700e+04            16.000000     1.180000e+03
# max          4.052662e+07        232773.000000     2.422417e+07
#
#        avg_provider_per_county  total_payment
# count            990509.000000   9.905090e+05
# mean                 24.085372   1.324452e+07
# std                  95.010677   4.753706e+08
# min                   0.000000   5.046500e+02
# 25%                   2.000000   8.616682e+04
# 50%                   5.000000   4.245737e+05
# 75%                  16.000000   2.155053e+06
# max                5558.000000   9.873104e+10

# %%
df_qpp.loc[df_qpp['total_payment'] > 1000000000]
#higher payments are due to the aggregation level, remove the ALL aggregations to leave only county level
# Out:
#         year                                 service_type  \
# 0       2018        Ambulance (Emergency & Non-Emergency)
# 3165    2018                        Ambulance (Emergency)
# 6316    2018                    Ambulance (Non-Emergency)
# 9284    2018               Cardiac Rehabilitation Program
# 14676   2018  Clinical Laboratory (Billing Independently)
# ...      ...                                          ...
# 984455  2022                     Skilled Nursing Facility
# 984460  2022                     Skilled Nursing Facility
# 984463  2022                     Skilled Nursing Facility
# 984649  2022                     Skilled Nursing Facility
# 985031  2022                     Skilled Nursing Facility
#
#            aggregation_level    state       county  number_ffs_members  \
# 0       NATION + TERRITORIES  --ALL--      --ALL--            34139906
# 3165    NATION + TERRITORIES  --ALL--      --ALL--            34130763
# 6316    NATION + TERRITORIES  --ALL--      --ALL--            33992860
# 9284    NATION + TERRITORIES  --ALL--      --ALL--            32544530
# 14676   NATION + TERRITORIES  --ALL--      --ALL--            34146233
# ...                      ...      ...          ...                 ...
# 984455                 STATE       PA      --ALL--             1606945
# 984460                 STATE       TX      --ALL--             2594364
# 984463                 STATE       VA      --ALL--             1187498
# 984649                COUNTY       CA  Los Angeles              812149
# 985031                COUNTY       IL         Cook              563399
#
#         number_of_providers avg_user_per_provider  number_of_users  \
# 0                      8784                489.44          4299207
# 3165                   8430                459.42          3872890
# 6316                   8772                173.69          1523598
# 9284                   2294                 83.34           191189
# 14676                  2568                6146.0         15782920
# ...                     ...                   ...              ...
# 984455                  687                 85.68            58862
# 984460                 1172                  76.2            89311
# 984463                  293                137.61            40320
# 984649                  420                 77.71            32640
# 985031                  275                 88.81            24424
#
#         avg_provider_per_county number_of_dual_eligible_users  total_payment  \
# 0                         39.38                     1,417,851   3.966064e+09
# 3165                      32.30                     1,290,112   2.708130e+09
# 6316                      39.38                       535,199   1.232323e+09
# 9284                       4.85                        22,148   3.027457e+09
# 14676                     98.98                     3,415,596   4.330650e+09
# ...                         ...                           ...            ...
# 984455                    38.54                        11,480   1.838070e+09
# 984460                    44.83                        26,032   3.387342e+09
# 984463                    12.93                         6,401   1.343432e+09
# 984649                   420.00                        18,543   2.369288e+09
# 985031                   275.00                         6,352   1.036636e+09
#
#        moratorium
# 0
# 3165
# 6316
# 9284
# 14676
# ...           ...
# 984455         No
# 984460         No
# 984463         No
# 984649         No
# 985031         No
#
# [1394 rows x 13 columns]

# %%
#convert ALL values in aggregation_level to NaN
df_qpp.loc[df_qpp['aggregation_level'] == 'NATION + TERRITORIES'] = np.nan

# %%
#create new df with NaN removed
qpp_clean = df_qpp[df_qpp['aggregation_level'].isnull() == False]

# %%
#confirm shape after NaN removed
qpp_clean.shape
# Out:
# (990169, 13)

# %%
#check values of payments > 1000000000
qpp_clean.loc[qpp_clean['total_payment'] > 1000000000]

# %% [markdown]
# ## B. Explore state level aggregation

# %%
# create df for state level aggregation
df_state_agg = df_qpp[df_qpp['aggregation_level'] == 'STATE']

# %%
df_state_agg.head(10)
# Out:
#     year                           service_type aggregation_level state  \
# 1   2018  Ambulance (Emergency & Non-Emergency)             STATE    AL
# 2   2018  Ambulance (Emergency & Non-Emergency)             STATE    AK
# 3   2018  Ambulance (Emergency & Non-Emergency)             STATE    AZ
# 4   2018  Ambulance (Emergency & Non-Emergency)             STATE    AR
# 5   2018  Ambulance (Emergency & Non-Emergency)             STATE    CA
# 6   2018  Ambulance (Emergency & Non-Emergency)             STATE    CO
# 7   2018  Ambulance (Emergency & Non-Emergency)             STATE    CT
# 8   2018  Ambulance (Emergency & Non-Emergency)             STATE    DE
# 9   2018  Ambulance (Emergency & Non-Emergency)             STATE    DC
# 10  2018  Ambulance (Emergency & Non-Emergency)             STATE    FL
#
#      county  number_ffs_members  number_of_providers avg_user_per_provider  \
# 1   --ALL--            528819.0                149.0                 497.2
# 2   --ALL--             65846.0                 32.0                212.88
# 3   --ALL--            679296.0                176.0                376.38
# 4   --ALL--            421631.0                 89.0                597.22
# 5   --ALL--           3228528.0                329.0               1143.47
# 6   --ALL--            486851.0                136.0                324.34
# 7   --ALL--            397274.0                181.0                358.63
# 8   --ALL--            158421.0                 95.0                225.61
# 9   --ALL--             62096.0                 23.0                397.57
# 10  --ALL--           2203766.0                224.0               1305.31
#
#     number_of_users  avg_provider_per_county number_of_dual_eligible_users  \
# 1           74083.0                    12.08                        27,907
# 2            6812.0                     6.60                         2,824
# 3           66243.0                    69.63                        13,476
# 4           53153.0                     8.16
# 5          376202.0                    80.84                       177,350
# 6           44110.0                    15.92                        12,255
# 7           64912.0                    52.34                        31,477
# 8           21433.0                    51.99                         4,387
# 9            9144.0                    23.00                         5,612
# 10         292390.0                    34.98                        85,236
#
#     total_payment moratorium
# 1    7.676008e+07         No
# 2    5.690912e+06         No
# 3    4.592878e+07         No
# 4    4.777772e+07         No
# 5    3.354311e+08         No
# 6    3.312693e+07         No
# 7    6.666871e+07         No
# 8    1.615931e+07         No
# 9    7.328845e+06         No
# 10   2.254507e+08         No

# %%
df_state_agg.shape
# Out:
# (17291, 13)

# %%
#check descriptive statistics of df state agg
df_state_agg.describe()
# Out:
#        number_ffs_members  number_of_providers  number_of_users  \
# count        1.729100e+04         17291.000000     1.729100e+04
# mean         7.267929e+05           704.127928     1.034866e+05
# std          7.065134e+05          1762.804640     2.053715e+05
# min          6.996000e+03             0.000000     1.100000e+01
# 25%          2.300220e+05            63.000000     8.441500e+03
# 50%          5.163380e+05           161.000000     3.106600e+04
# 75%          9.644970e+05           511.000000     9.331750e+04
# max          3.846711e+06         19475.000000     2.117896e+06
#
#        avg_provider_per_county  total_payment
# count             17291.000000   1.729100e+04
# mean                 82.054431   2.527887e+08
# std                 189.252094   6.783551e+08
# min                   0.000000   1.626250e+03
# 25%                   7.600000   1.182441e+07
# 50%                  22.250000   4.196357e+07
# 75%                  65.690000   1.600485e+08
# max                2058.760000   9.418766e+09

# %%
#export state agg to pickle
df_state_agg.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'state_agg.pkl'))

# %%
#export state agg to csv
df_state_agg.to_csv(os.path.join(path, '02 Data','Prepared Data', 'state_agg.csv'))

# %% [markdown]
# ## C. Explore County Level Aggregation

# %%
# create df for county level aggregation
df_county_agg = df_qpp[df_qpp['aggregation_level'] == 'COUNTY']

# %%
df_county_agg.shape
# Out:
# (972878, 13)

# %%
df_county_agg.head()
# Out:
#     year                           service_type aggregation_level state  \
# 52  2018  Ambulance (Emergency & Non-Emergency)            COUNTY    AL
# 53  2018  Ambulance (Emergency & Non-Emergency)            COUNTY    AL
# 54  2018  Ambulance (Emergency & Non-Emergency)            COUNTY    AL
# 55  2018  Ambulance (Emergency & Non-Emergency)            COUNTY    AL
# 56  2018  Ambulance (Emergency & Non-Emergency)            COUNTY    AL
#
#      county  number_ffs_members  number_of_providers avg_user_per_provider  \
# 52  Autauga              4307.0                  6.0                 96.17
# 53  Baldwin             23925.0                 11.0                267.73
# 54  Barbour              3497.0                  8.0                 60.38
# 55     Bibb              2002.0                  6.0                 48.83
# 56   Blount              5061.0                  9.0                 79.11
#
#     number_of_users  avg_provider_per_county number_of_dual_eligible_users  \
# 52            577.0                      6.0                           175
# 53           2945.0                     11.0                           540
# 54            483.0                      8.0                           234
# 55            293.0                      6.0                           135
# 56            712.0                      9.0                           170
#
#     total_payment moratorium
# 52      511203.03         No
# 53     2257208.93         No
# 54      701162.88         No
# 55      424248.07         No
# 56      668045.99         No

# %%
df_county_agg.describe()
# Out:
#        number_ffs_members  number_of_providers  number_of_users  \
# count       972878.000000        972878.000000    972878.000000
# mean         12917.318971            23.018349      1839.271391
# std          31144.427233            92.065402      7424.486892
# min             19.000000             0.000000        11.000000
# 25%           2170.000000             2.000000        86.000000
# 50%           4425.000000             5.000000       298.000000
# 75%          10918.000000            15.000000      1091.000000
# max         818592.000000          5558.000000    447517.000000
#
#        avg_provider_per_county  total_payment
# count            972878.000000   9.728780e+05
# mean                 23.018349   4.492823e+06
# std                  92.065402   2.585388e+07
# min                   0.000000   5.046500e+02
# 25%                   2.000000   8.345478e+04
# 50%                   5.000000   4.029456e+05
# 75%                  15.000000   1.962914e+06
# max                5558.000000   2.369288e+09

# %%
#export county agg to pickle
df_county_agg.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'county_agg.pkl'))

# %%
#export county agg to csv
df_county_agg.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'county_agg.csv'))

# %% [markdown]
# ## D. Check stats after separation of county and state aggregation

# %% [markdown]
# #### Stats for state level aggregations

# %%
#create histogram of total_payment to check distribution of state aggregation
sns.histplot(df_state_agg['total_payment'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='total_payment', ylabel='Count'>

# %%
#check payment values > 1000000000
df_state_agg.loc[df_state_agg['total_payment'] > 1000000000]
# Out:
#         year              service_type aggregation_level state   county  \
# 17868   2018                  Dialysis             STATE    CA  --ALL--
# 17873   2018                  Dialysis             STATE    FL  --ALL--
# 17896   2018                  Dialysis             STATE    NY  --ALL--
# 17907   2018                  Dialysis             STATE    TX  --ALL--
# 23212   2018               Home Health             STATE    CA  --ALL--
# ...      ...                       ...               ...   ...      ...
# 984450  2022  Skilled Nursing Facility             STATE    NC  --ALL--
# 984452  2022  Skilled Nursing Facility             STATE    OH  --ALL--
# 984455  2022  Skilled Nursing Facility             STATE    PA  --ALL--
# 984460  2022  Skilled Nursing Facility             STATE    TX  --ALL--
# 984463  2022  Skilled Nursing Facility             STATE    VA  --ALL--
#
#         number_ffs_members  number_of_providers avg_user_per_provider  \
# 17868            3220226.0                659.0                 63.88
# 17873            2202175.0                455.0                 53.85
# 17896            1982092.0                292.0                  77.4
# 17907            2164856.0                650.0                 59.42
# 23212            3228315.0               1255.0                245.41
# ...                    ...                  ...                   ...
# 984450           1221526.0                435.0                 91.93
# 984452           1313223.0                895.0                 63.23
# 984455           1606945.0                687.0                 85.68
# 984460           2594364.0               1172.0                  76.2
# 984463           1187498.0                293.0                137.61
#
#         number_of_users  avg_provider_per_county  \
# 17868           42096.0                    65.55
# 17873           24502.0                    20.66
# 17896           22600.0                    21.60
# 17907           38623.0                    34.92
# 23212          307987.0                   233.38
# ...                 ...                      ...
# 984450          39990.0                    14.07
# 984452          56589.0                    37.08
# 984455          58862.0                    38.54
# 984460          89311.0                    44.83
# 984463          40320.0                    12.93
#
#        number_of_dual_eligible_users  total_payment moratorium
# 17868                         25,649   2.474779e+09         No
# 17873                         11,883   1.201505e+09         No
# 17896                          7,451   1.240829e+09         No
# 17907                         18,864   1.916792e+09         No
# 23212                        148,888   4.218860e+09         No
# ...                              ...            ...        ...
# 984450                         8,647   1.308677e+09         No
# 984452                         9,527   1.887855e+09         No
# 984455                        11,480   1.838070e+09         No
# 984460                        26,032   3.387342e+09         No
# 984463                         6,401   1.343432e+09         No
#
# [1026 rows x 13 columns]

# %%
df_state_agg['total_payment'].mean()
# Out:
# 252788671.78292406

# %%
df_state_agg['total_payment'].median()
# Out:
# 41963570.34

# %%
df_state_agg['total_payment'].min()
# Out:
# 1626.25

# %%
df_state_agg['total_payment'].max()
# Out:
# 9418765824.55

# %% [markdown]
# #### Stats for county level aggregations

# %%
#check payment values > 1000000000
df_county_agg.loc[df_county_agg['total_payment'] > 1000000000]
# Out:
#         year                                  service_type aggregation_level  \
# 23443   2018                                   Home Health            COUNTY
# 29456   2018  Independent Diagnostic Testing Facility Pt A            COUNTY
# 29861   2018  Independent Diagnostic Testing Facility Pt A            COUNTY
# 52577   2018                      Skilled Nursing Facility            COUNTY
# 52967   2018                      Skilled Nursing Facility            COUNTY
# ...      ...                                           ...               ...
# 955619  2022                                   Home Health            COUNTY
# 961693  2022  Independent Diagnostic Testing Facility Pt A            COUNTY
# 962098  2022  Independent Diagnostic Testing Facility Pt A            COUNTY
# 984649  2022                      Skilled Nursing Facility            COUNTY
# 985031  2022                      Skilled Nursing Facility            COUNTY
#
#        state       county  number_ffs_members  number_of_providers  \
# 23443     CA  Los Angeles            716885.0                827.0
# 29456     CA  Los Angeles            716885.0                463.0
# 29861     IL         Cook            541547.0                357.0
# 52577     CA  Los Angeles            716885.0                409.0
# 52967     IL         Cook            541547.0                279.0
# ...      ...          ...                 ...                  ...
# 955619    CA  Los Angeles            812149.0               1215.0
# 961693    CA  Los Angeles            812149.0                466.0
# 962098    IL         Cook            563399.0                342.0
# 984649    CA  Los Angeles            812149.0                420.0
# 985031    IL         Cook            563399.0                275.0
#
#        avg_user_per_provider  number_of_users  avg_provider_per_county  \
# 23443                 126.42         104547.0                    827.0
# 29456                 588.11         272297.0                    463.0
# 29861                 880.68         314404.0                    357.0
# 52577                  80.73          33018.0                    409.0
# 52967                 105.75          29504.0                    279.0
# ...                      ...              ...                      ...
# 955619                 91.23         110840.0                   1215.0
# 961693                560.48         261186.0                    466.0
# 962098                830.74         284113.0                    342.0
# 984649                 77.71          32640.0                    420.0
# 985031                 88.81          24424.0                    275.0
#
#        number_of_dual_eligible_users  total_payment moratorium
# 23443                         67,860   1.731338e+09         No
# 29456                        116,007   1.326328e+09         No
# 29861                         66,999   1.340563e+09         No
# 52577                         18,306   1.881704e+09         No
# 52967                          8,167   1.128528e+09         No
# ...                              ...            ...        ...
# 955619                        72,125   2.274269e+09         No
# 961693                       102,484   1.606094e+09         No
# 962098                        44,444   1.508048e+09         No
# 984649                        18,543   2.369288e+09         No
# 985031                         6,352   1.036636e+09         No
#
# [82 rows x 13 columns]

# %%
df_county_agg['total_payment'].mean()
# Out:
# 4492823.276709455

# %%
df_county_agg['total_payment'].median()
# Out:
# 402945.58999999997

# %%
df_county_agg['total_payment'].min()
# Out:
# 504.65

# %%
df_county_agg['total_payment'].max()
# Out:
# 2369287664.37
